# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
atlanta_crime_data = "./COBRA-2009-2018.csv"


# Read the Mouse and Drug Data and the Clinical Trial Data
atlanta_crime_df = pd.read_csv(atlanta_crime_data)

atlanta_crime_df.head()
# Out:
#    Report Number Report Date  Occur Date  Occur Time Possible Date  \
# 0       90010930  2009-01-01  2009-01-01        1145    2009-01-01
# 1       90011083  2009-01-01  2009-01-01        1330    2009-01-01
# 2       90011208  2009-01-01  2009-01-01        1500    2009-01-01
# 3       90011218  2009-01-01  2009-01-01        1450    2009-01-01
# 4       90011289  2009-01-01  2009-01-01        1600    2009-01-01
#
#    Possible Time   Beat Apartment Office Prefix Apartment Number  \
# 0         1148.0  408.0                     NaN              NaN
# 1         1330.0  506.0                     NaN              NaN
# 2         1520.0  413.0                     NaN              NaN
# 3         1510.0  204.0                     NaN              NaN
# 4         1700.0  408.0                     NaN              NaN
#
#                       Location Shift Occurence Location Type  \
# 0         2841 GREENBRIAR PKWY       Day Watch             8
# ...

# %%
atlanta_crime_2018_df = atlanta_crime_df.loc[atlanta_crime_df['Report Date'].str.contains('2018')]

Georgia_Tech_Crime_2018 = atlanta_crime_2018_df.loc[atlanta_crime_2018_df['Neighborhood']=='Georgia Tech']

Georgia_Tech_Crime_2018.head()
#print(len(Georgia_Tech_Crime_2018))
# Out:
#         Report Number Report Date  Occur Date  Occur Time Possible Date  \
# 306301      182051719  2018-07-24  2018-07-24        1630    2018-07-24
# 307534      182222078  2018-08-10  2018-08-10        1910    2018-08-10
# 307661      182240252  2018-08-12  2018-08-11        2230    2018-08-12
# 311281      182752340  2018-10-02  2018-10-02        1945    2018-10-02
# 314669      183231846  2018-11-19  2018-11-19        1830    2018-11-19
#
#         Possible Time   Beat Apartment Office Prefix Apartment Number  \
# 306301         1650.0  504.0                     NaN              NaN
# 307534         1925.0  504.0                     NaN              NaN
# 307661          200.0  505.0                     NaN              NaN
# 311281         2015.0  504.0                     NaN              NaN
# 314669         1920.0  504.0                     NaN              NaN
#
#                               Location Shift Occurence Location Type  \
# ...
