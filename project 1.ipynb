# 84       90010536    1/1/2009    1/1/2009         410      1/1/2009
# 85       90011359    1/1/2009    1/1/2009        1500      1/1/2009
# 86       83662137    1/1/2009  12/31/2008        2315    12/31/2008
# 87       90011341    1/1/2009    1/1/2009        1700      1/1/2009
# 88       90011684    1/1/2009    1/1/2009        2145      1/1/2009
# 89       90010373    1/1/2009    1/1/2009         200      1/1/2009
# 90       90011106    1/1/2009    1/1/2009        1408      1/1/2009
# 91       83651892    1/1/2009  12/23/2008        1200    12/30/2008
# 92       90010061    1/1/2009    1/1/2009          10      1/1/2009
# 93       90010143    1/1/2009  12/31/2008        1600      1/1/2009
# 94       90010269    1/1/2009    1/1/2009          35      1/1/2009
# 95       90010307    1/1/2009  12/31/2008        2245      1/1/2009
# 96       90010369    1/1/2009  12/31/2008        2200      1/1/2009
# 97       90010568    1/1/2009  12/31/2008        2300      1/1/2009
# 98       90010666    1/1/2009    1/1/2009         654      1/1/2009
# 99       90010889    1/1/2009  12/31/2008        2300      1/1/2009
#
#     Possible Time   Beat Apartment Office Prefix Apartment Number  \
# 0          1148.0  408.0                     NaN              NaN
# 1          1330.0  506.0                     NaN              NaN
# 2          1520.0  413.0                     NaN              NaN
# 3          1510.0  204.0                     NaN              NaN
# 4          1700.0  408.0                     NaN              NaN
# 5          1645.0  607.0                     NaN              NaN
# 6          1815.0  308.0                     NaN              NaN
# 7          2110.0  204.0                     NaN              NaN
# 8           820.0  408.0                     NaN              NaN
# 9           100.0  506.0                     NaN              NaN
# 10          135.0  607.0                     NaN              NaN
# 11          130.0  607.0                     NaN              NaN
# 12          900.0  406.0                     NaN              NaN
# 13          800.0  205.0                     NaN              313
# 14          923.0  605.0                     NaN              NaN
# 15          945.0  511.0                     NaN             1305
# 16         1137.0  505.0                     NaN              NaN
# 17         1230.0  507.0                     NaN              NaN
# 18         2200.0  504.0                     NaN              NaN
# 19          700.0  505.0                     NaN              NaN
# 20         1200.0  413.0                     NaN              NaN
# 21         1200.0  108.0                     NaN             1234
# 22         1545.0  506.0                     NaN              NaN
# 23         1630.0  202.0                     NaN              NaN
# 24         1938.0  413.0                     NaN              NaN
# 25         2000.0  503.0                     NaN              NaN
# 26         2025.0  408.0                     NaN              NaN
# 27         2240.0  109.0                     NaN              NaN
# 28         2220.0  507.0                     NaN              NaN
# 29         1400.0  306.0                     NaN               87
# ..            ...    ...                     ...              ...
# 70          223.0  307.0                     NaN             2601
# 71          200.0  104.0                     NaN              NaN
# 72          600.0  303.0                     NaN             3313
# 73          705.0  406.0                     NaN              NaN
# 74          850.0  408.0                     NaN              NaN
# 75         1915.0  510.0                     NaN              NaN
# 76          105.0  205.0                     NaN              NaN
# 77          825.0  509.0                     NaN              NaN
# 78         1230.0  412.0                     NaN              NaN
# 79         1840.0  508.0                     NaN              NaN
# 80         1900.0  411.0                     NaN              NaN
# 81          130.0  509.0                     NaN              NaN
# 82          730.0  105.0                     NaN               15
# 83         1927.0  301.0                     NaN              NaN
# 84          411.0  402.0                     NaN              NaN
# 85         1515.0  307.0                     NaN              NaN
# 86         2339.0  107.0                     NaN                4
# 87         1701.0  110.0                     NaN              NaN
# 88         2149.0  306.0                     NaN              NaN
# 89          230.0  507.0                     NaN              316
# 90         1500.0  611.0                     NaN              NaN
# 91         1900.0  607.0                     NaN              NaN
# 92           20.0  309.0                     NaN              NaN
# 93           45.0  609.0                     NaN              NaN
# 94           45.0  403.0                     NaN              NaN
# 95          145.0  402.0                     NaN             B102
# 96          200.0  204.0                     NaN             A302
# 97          430.0  408.0                     NaN            O-201
# 98          654.0  611.0                     NaN              260
# 99          300.0  610.0                     NaN              NaN
#
#                                   Location Shift Occurence Location Type  \
# 0                     2841 GREENBRIAR PKWY       Day Watch             8
# 1                           12 BROAD ST SW       Day Watch             9
# 2              3500 MARTIN L KING JR DR SW         Unknown             8
# 3                     3393 PEACHTREE RD NE   Evening Watch             8
# 4                  2841 GREENBRIAR PKWY SW         Unknown             8
# 5                      1217 CAROLINE ST NE   Evening Watch            24
# 6                2685 METROPOLITAN PARKWAY   Evening Watch            12
# 7                        3393 PEACHTREE RD   Evening Watch             8
# 8                      3030 HEADLAND DR SW       Day Watch            12
# 9                       360 MARIETTA ST NW   Morning Watch            18
# 10                      195 ARIZONA AVE NE   Morning Watch            13
# 11                       58 SAUNDERS ST NE   Morning Watch            20
# 12                     1457 VENETIAN DR SW       Day Watch            20
# 13                     3558 PIEDMONT RD NE       Day Watch            18
# 14                       456 CANDLER ST NE       Day Watch            13
# 15                       626 DEKALB AVE SE       Day Watch            18
# 16                           422 9TH ST NE       Day Watch            13
# 17                   590 W PEACHTREE ST NW       Day Watch            18
# 18                         188 14TH STREET       Day Watch            18
# 19                       897 MONROE CIR NE       Day Watch            13
# 20                       4076 BREWER DR SW   Evening Watch           NaN
# 21                   162O HOLLY WOOD DR NW   Evening Watch            18
# 22   IVAN ALLEN JR BLVD NW / VENABLE ST NW   Evening Watch            13
# 23  135 W WIEUCA RD NW @CHASTAIN CITY PARK   Evening Watch            13
# 24                    501 WILSON MILLRD SW   Evening Watch            13
# 25           6TH ST NE / W PEACHTREE ST NE   Evening Watch            13
# 26                 2841 GREENBRIAR PKWY SW   Evening Watch            18
# 27                      3114 COLLIER DR NW   Morning Watch            13
# 28                          31 BAKER ST NE   Evening Watch            18
# 29                          624 AMAL DR SW   Evening Watch            26
# ..                                     ...             ...           ...
# 70                    585 MCWILLIAMS RD SE   Morning Watch            18
# 71                     2174 PENELOPE ST NW         Unknown            18
# 72                      765 MCDANIEL ST SW       Day Watch            18
# 73                    1345 WESTRIDGE RD SW       Day Watch            20
# 74                  1812 FORT VALLEY DR SW       Day Watch            20
# 75                           356 BOULEVARD   Evening Watch            23
# 76             BUCKEAD AVE./GRANDVIEW AVE.   Morning Watch            99
# 77               160 JOHN WESLEY DOBBS AVE       Day Watch            23
# 78                   3202 MARTIN L KING DR       Day Watch            10
# 79                          90 BROAD ST SW   Evening Watch            13
# 80             2181 MARTIN L KING JR DR NW   Evening Watch            13
# 81                      54 PEACHTREE ST SW   Morning Watch            13
# 82                        345 LANIER ST NW       Day Watch            26
# 83                       307 RICHARDSON ST   Evening Watch             7
# 84                  17OO N OLYMPIAN WAY SW   Morning Watch            13
# 85                        2305 MACON DR SW   Evening Watch            20
# 86                     625 JOSEPH E LOWERY   Morning Watch            26
# 87               BANKHEAD HWY @ MAYNARD CT       Day Watch            13
# 88                    2043 LAKEWOOD TRL SE   Evening Watch            20
# 89                   115 W PEACHTREE PL NW   Morning Watch            13
# 90                     2021 PHILLIPS DR SE       Day Watch            20
# 91                      2163 RIDGEDALE RD.   Evening Watch            20
# 92                       501 TUFTON TRL SE   Morning Watch            20
# 93                       695 VERNON AVE SE   Morning Watch            20
# 94                    1145 PRINCESS AVE SW   Morning Watch            20
# 95          1530 RALPH D ABERNATHY BLVD SW   Morning Watch            26
# 96                        3200 LENOX RD NE   Morning Watch            26
# 97                  1999 BENT CREEK WAY SW   Morning Watch            26
# 98                  1090 MCDONOUGH BLVD SE       Day Watch            26
# 99                         1583 MAY AVE SE   Morning Watch            20
#
#              UCR Literal  UCR # IBR Code             Neighborhood NPU  \
# 0    LARCENY-NON VEHICLE    630     2303               Greenbriar   R
# 1    LARCENY-NON VEHICLE    630     2303                 Downtown   M
# 2    LARCENY-NON VEHICLE    630     2303               Adamsville   H
# 3    LARCENY-NON VEHICLE    630     2303                    Lenox   B
# 4    LARCENY-NON VEHICLE    630     2303               Greenbriar   R
# 5    LARCENY-NON VEHICLE    630     2303                 Edgewood   O
# 6    LARCENY-NON VEHICLE    630     2303           Venetian Hills   S
# 7    LARCENY-NON VEHICLE    630     2303                    Lenox   B
# 8    LARCENY-NON VEHICLE    630     2303               Greenbriar   R
# 9   LARCENY-FROM VEHICLE    640     2305                 Downtown   M
# 10  LARCENY-FROM VEHICLE    640     2305                 Edgewood   O
# 11  LARCENY-FROM VEHICLE    640     2305                 Kirkwood   O
# 12  LARCENY-FROM VEHICLE    640     2305           Venetian Hills   S
# 13  LARCENY-FROM VEHICLE    640     2305          Buckhead Forest   B
# 14  LARCENY-FROM VEHICLE    640     2305             Candler Park   N
# 15  LARCENY-FROM VEHICLE    640     2305          Old Fourth Ward   M
# 16  LARCENY-FROM VEHICLE    640     2305                  Midtown   E
# 17  LARCENY-FROM VEHICLE    640     2305                 Downtown   M
# 18  LARCENY-FROM VEHICLE    640     2305                  Midtown   E
# 19  LARCENY-FROM VEHICLE    640     2305                  Midtown   E
# 20  LARCENY-FROM VEHICLE    640     2305      Wilson Mill Meadows   H
# 21  LARCENY-FROM VEHICLE    640     2305          Scotts Crossing   G
# 22  LARCENY-FROM VEHICLE    640     2305                 Downtown   M
# 23  LARCENY-FROM VEHICLE    640     2305            Chastain Park   A
# 24  LARCENY-FROM VEHICLE    640     2305      Wilson Mill Meadows   H
# 25  LARCENY-FROM VEHICLE    640     2305                  Midtown   E
# 26  LARCENY-FROM VEHICLE    640     2305               Greenbriar   R
# 27  LARCENY-FROM VEHICLE    640     2305          Collier Heights   I
# 28   LARCENY-NON VEHICLE    680     2307                 Downtown   M
# 29  LARCENY-FROM VEHICLE    650     2304             Amal Heights   Y
# ..                   ...    ...      ...                      ...  ..
# 79  33.75204  -84.39282
# 80  33.75260  -84.46294
# 81  33.75286  -84.39120
# 82  33.76449  -84.43920
# 83  33.74065  -84.39702
# 84  33.73613  -84.44461
# 85  33.69155  -84.39163
# 86  33.74865  -84.41763
# 87  33.79361  -84.50024
# 88  33.69816  -84.37791
# 89  33.76410  -84.39110
# 90  33.69866  -84.35403
# 91  33.75298  -84.31680
# 92  33.66477  -84.38430
# 93  33.73499  -84.35802
# 94  33.72374  -84.42549
# 95  33.74307  -84.43767
# 96  33.84221  -84.35822
# 97  33.70087  -84.46574
# 98  33.70449  -84.35193
# 99  33.73875  -84.33585
#
# [100 rows x 19 columns]

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317904 entries, 0 to 317903
# Data columns (total 19 columns):
# Report Number              317904 non-null int64
# Report Date                317904 non-null object
# Occur Date                 317904 non-null object
# Occur Time                 317904 non-null int64
# Possible Date              317886 non-null object
# Possible Time              317885 non-null float64
# Beat                       317694 non-null float64
# Apartment Office Prefix    9570 non-null object
# Apartment Number           64077 non-null object
# Location                   317902 non-null object
# Shift Occurence            317904 non-null object
# Location Type              310373 non-null object
# UCR Literal                317904 non-null object
# UCR #                      317904 non-null int64
# IBR Code                   317748 non-null object
# Neighborhood               306464 non-null object
# NPU                        317780 non-null object
# Latitude                   317904 non-null float64
# Longitude                  317904 non-null float64
# dtypes: float64(4), int64(3), object(12)
# memory usage: 46.1+ MB

# %%
#change date from strint
crime_df["Occur Date"] = pd.to_datetime(crime_df["Occur Date"], format='%m/%d/%Y')
temp = crime_df["Occur Date"]
temp.head()
# Out:
# 0   2009-01-01
# 1   2009-01-01
# 2   2009-01-01
# 3   2009-01-01
# 4   2009-01-01
# Name: Occur Date, dtype: datetime64[ns]

# %%
#changed date to month and year
New_date = pd.DataFrame()
New_date["Year_s"] = crime_df["Occur Date"].astype(str).apply(lambda x: x[0:4])
New_date["Month_s"] = crime_df["Occur Date"].astype(str).apply(lambda x: x[5:7])

# %%
New_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317904 entries, 0 to 317903
# Data columns (total 2 columns):
# Year_s     317904 non-null object
# Month_s    317904 non-null object
# dtypes: object(2)
# memory usage: 4.9+ MB

# %%
#made DF for non res crimes and res crimes
df_res = crime_df[crime_df['UCR Literal'] == 'BURGLARY-RESIDENCE']
df_nonres = crime_df[crime_df['UCR Literal'] == 'BURGLARY-NONRES']

# %%
#doing groupby funcction for res crimes
res_df = crime_df.groupby(['UCR Literal'])
print(res_df)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000299B5BB99B0>

# %%
res_df["New_date"(temp)"].sum()
# Out:
#   File "<ipython-input-114-4c75e2f4981e>", line 1
#     res_df["New_date"(temp)"].sum()
#                                    ^
# SyntaxError: EOL while scanning string literal

# %%
print(df_nonres)
# Out:
#         Report Number Report Date Occur Date  Occur Time Possible Date  \
# 106          90010680    1/1/2009 2009-01-01         711      1/1/2009
# 107          90010681    1/1/2009 2008-12-31        2030      1/1/2009
# 108          90010801    1/1/2009 2009-01-01         945      1/1/2009
# 109          90010963    1/1/2009 2009-01-01         400      1/1/2009
# 110          90010975    1/1/2009 2009-01-01        1200      1/1/2009
# 114          90020981    1/2/2009 2008-01-02           0      1/2/2008
#
#                                           Location Shift Occurence  \
# 106                           2359 PEACHTREE RD NE       Day Watch
# 107                    1300 JOSEPH E BOONE BLVD NW       Day Watch
# 108              1020 DONALD LEE HOLLOWELL PKWY NW       Day Watch
# 109                               595 NORTH AVE NW       Day Watch
# 110                          286 WILSON MILL RD SW   Evening Watch
# 114                             200 MEMORIAL DR SW   Evening Watch
# 119                  994 RALPH D ABERNATHY BLVD SW   Morning Watch
# 120                           3393 PEACHTREE RD NE   Morning Watch
# 121                              1150 ASTOR AVE SW       Day Watch
# 122                     775 JOSEPH E BOONE BLVD NW       Day Watch
# 123                               691 IMAGE AVE NW       Day Watch
# 124                              172 DAHLIA AVE NW   Evening Watch
# 360                         2910 CAMPBELLTON RD SW   Morning Watch
# 361                  2655 DONALD LEE HOLLOWELL PKY       Day Watch
# 362                          286 WILSON MILL RD SW       Day Watch
# 363                              820 BEECHER CT SW       Day Watch
# 364                    1371 JOSEPH E BOONE BLVD NW         Unknown
# 365                               990 BRADY AVE NW       Day Watch
# 366                                 1625 NORTH AVE   Evening Watch
# 379                                49 BOULEVARD SE   Morning Watch
# 380                            712 MORELAND AVE SE   Morning Watch
# 381     286 WILSON MILL RD SW @ADAMSVILLE ELEMENTA       Day Watch
# 382                            572 EDGEWOOD AVE NE   Morning Watch
# 383                            581 EDGEWOOD AVE SE   Morning Watch
# 384                           1104 MORELAND AVE SE       Day Watch
# 385                          216 PONCE DE LEON AVE       Day Watch
# 386                         3272 BROWNS MILL RD SE       Day Watch
# 387                               148 GLENWOOD AVE       Day Watch
# 388                         1942 HOWELL MILL RD NW   Evening Watch
# 389               135 ANDREW YOUNG INTERNA BLVD NW   Morning Watch
# ...                                            ...             ...
# 316820                        2915 PEACHTREE RD NE       Day Watch
# 316846                 3136 MARTIN L KING JR DR SW       Day Watch
# 316847                         2400 PARKLAND DR NE         Unknown
# 316876                   834 INMAN VILLAGE PKWY NE       Day Watch
# 316877            1085 LINDBERGH DR NE @VARSITY JR       Day Watch
# 317055                              1005 LEE ST SW   Morning Watch
# 317056                       2900 PEACHTREE RD NW    Morning Watch
# 317057                         2400 PARKLAND DR NE       Day Watch
# 317058                      1801 HOWELL MILL RD NW   Morning Watch
# 317142                      1801 HOWELL MILL RD NW   Morning Watch
# 317143              1541 RALPH D ABERNATHY BLVD SW   Morning Watch
# 317144                            507 BISHOP ST NW       Day Watch
# 317224                            3355 LENOX RD NE   Morning Watch
# 317225                            464 BISHOP ST NW         Unknown
# 317226                            300 PETERS ST SW   Evening Watch
# 317373                      2159 CAMPBELLTON RD SW   Morning Watch
# 317374                      2151 CAMPBELLTON RD SW   Morning Watch
# 317439                   2685 METROPOLITAN PKWY SW   Morning Watch
# 317440                     2497 FORREST PARK RD SE   Evening Watch
# 317456                            119 MARONA ST NE   Evening Watch
# 317457                             44 WARREN ST SE       Day Watch
# 317488                     2444 FORREST PARK RD SE   Morning Watch
# 317567                      959 CONSTITUTION RD SE       Day Watch
# 317568                            464 BISHOP ST NW       Day Watch
# 317599                          3150 ROSWELL RD NW   Evening Watch
# 317624                            51 ELLIOTT ST SW   Morning Watch
# 317625                            239 WALKER ST SW   Morning Watch
# 317626                        955 HANK AARON DR SW       Day Watch
# 317718                          3163 ROSWELL RD NE   Morning Watch
# 317872                            1463 PRYOR RD SW   Morning Watch
#
#        Location Type      UCR Literal  UCR # IBR Code            Neighborhood  \
# 106               24  BURGLARY-NONRES    512     2203         Peachtree Hills
# 107               99  BURGLARY-NONRES    512     2203            Hunter Hills
# 108               24  BURGLARY-NONRES    512     2203                Bankhead
# 109                3  BURGLARY-NONRES    512     2203          English Avenue
# 110               11  BURGLARY-NONRES    512     2203        Wisteria Gardens
# 114               24  BURGLARY-NONRES    522     2205                Downtown
# 119               99  BURGLARY-NONRES    512     2203                West End
# 120                8  BURGLARY-NONRES    512     2203                   Lenox
# 121               26  BURGLARY-NONRES    512     2203            Sylvan Hills
# 122               17  BURGLARY-NONRES    512     2203          English Avenue
# 123               29  BURGLARY-NONRES    512     2203               Home Park
# 124               20  BURGLARY-NONRES    512     2203             Dixie Hills
# 360               21  BURGLARY-NONRES    512     2203               Southwest
# 361               99  BURGLARY-NONRES    512     2203         Carroll Heights
# 362               35  BURGLARY-NONRES    512     2203        Wisteria Gardens
# 363               11  BURGLARY-NONRES    512     2203     Cascade Avenue/Road
# 364               99  BURGLARY-NONRES    512     2203                Bankhead
# 365               24  BURGLARY-NONRES    512     2203               Home Park
# 366                7  BURGLARY-NONRES    512     2203              Grove Park
# 379               24  BURGLARY-NONRES    512     2203            Sweet Auburn
# 380               99  BURGLARY-NONRES    512     2203            East Atlanta
# 381               35  BURGLARY-NONRES    512     2203        Wisteria Gardens
# 382               24  BURGLARY-NONRES    512     2203         Old Fourth Ward
# 383               24  BURGLARY-NONRES    512     2203         Old Fourth Ward
# 384              NaN  BURGLARY-NONRES    512     2203            East Atlanta
# 385               21  BURGLARY-NONRES    512     2203                 Midtown
# 386                4  BURGLARY-NONRES    512     2203            Orchard Knob
# 387                4  BURGLARY-NONRES    512     2203              Summerhill
# 388               21  BURGLARY-NONRES    512     2203        Wildwood (NPU-C)
# 389               24  BURGLARY-NONRES    512     2203                Downtown
# ...              ...              ...    ...      ...                     ...
# 316820            21  BURGLARY-NONRES    512     2203            Garden Hills
# 316846            26  BURGLARY-NONRES    522     2205                     NaN
# 316847            19  BURGLARY-NONRES    522     2205       Lindbergh/Morosgo
# 316876             5  BURGLARY-NONRES    512     2203              Inman Park
# 316877            19  BURGLARY-NONRES    512     2203  Lindridge/Martin Manor
# 317055            23  BURGLARY-NONRES    512     2203            Oakland City
# 317056            12  BURGLARY-NONRES    512     2203  Peachtree Heights West
# 317057            26  BURGLARY-NONRES    512     2203       Lindbergh/Morosgo
# 317058           NaN  BURGLARY-NONRES    512     2203           Berkeley Park
# 317142            18  BURGLARY-NONRES    512     2203           Berkeley Park
# 317143            35  BURGLARY-NONRES    512     2203                Westview
# 317144           NaN  BURGLARY-NONRES    512     2203          Loring Heights
# 317224             5  BURGLARY-NONRES    512     2203                   Lenox
# 317225            26  BURGLARY-NONRES    512     2203          Loring Heights
# 317718   B  33.84144  -84.37828
# 317872   Y  33.71478  -84.39413
#
# [10180 rows x 19 columns]

# %%
fig, ax = plt.subplots()

ax.plot(temp, df_res, lable='crime_df')
ax.plot(temp, df_nonres, label='crime_df')

ax.plot(New_date, crime_df, color='#444444',
       linestyle='--', label='crime_df')

ax.legend()

ax.set_title('ResVsNon')
ax.set_xlabel('Date')
ax.set_ylabel('Type')

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-07f1442cb1a9> in <module>
#       1 fig, ax = plt.subplots()
#       2
# ----> 3 ax.plot(temp, df_res, lable='crime_df')
#       4 ax.plot(temp, df_nonres, label='crime_df')
#       5
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (317904,) and (47507, 19)

# %%
#fig = plt.figure(figsize=(15,5))

#ax1 = fig.add_axes([0, 0, 1, 1])
#ax2 = fig.add_axes([0, 0, 1, 1])

#ax1.set_title('res vs nonres(inert)')

#ax1.plot(crime_df['New_date'],
         #crime_df['df_nonres'],
         #color='green')

#ax2.plot(crime_df['New_date'],
         #crime_df['df_res'],
         #color='blue')
#plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-2f752d92fdd1> in <module>
#       1 sns.set(rc={'figure.figsize':(11.7,8.27)})
# ----> 2 sns.countplot(x = 'temp', data=crime_df, label= 'Shift Occurence', palette="plasma" )
#       3 plt.xticks(rotation='vertical')
#       4 plt.title("Crime Types")
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'temp'

# %%
#temp = crime_df["Occur Date"]
#df_res = crime_df["UCR Literal"]

#date_format = mpl_dates.DateFormatter('%b, %d, %Y')
#plt.plot_date(Date, Date2, fmt=date_format, linestyle='solid')

#plt.gcf().autofmt_xdate()

#plt.gca().xaxis.set_major_formatter(date_format)

#plt.title('Crime By Date')
#plt.xlabel('Date')
#plt.ylabel('Number Of Crimes')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1550         try:
# -> 1551             ret = self.converter.convert(x, self.units, self)
#    1552         except Exception as e:
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      64         # force an update so it also does type checking
# ---> 65         unit.update(values)
#      66
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     217             if not isinstance(val, (str, bytes)):
# --> 218                 raise TypeError("{val!r} is not a string".format(val=val))
#     219             if convertible:
#
# TypeError: <matplotlib.dates.DateFormatter object at 0x00000240DDB55EB8> is not a string
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-23-02c81921ed53> in <module>
#       3
#       4 date_format = mpl_dates.DateFormatter('%b, %d, %Y')
# ----> 5 plt.plot_date(Date, Date2, fmt=date_format, linestyle='solid')
#       6
#       7 plt.gcf().autofmt_xdate()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot_date(x, y, fmt, tz, xdate, ydate, data, **kwargs)
#    2797     return gca().plot_date(
#    2798         x, y, fmt=fmt, tz=tz, xdate=xdate, ydate=ydate, **({"data":
# -> 2799         data} if data is not None else {}), **kwargs)
#    2800
#    2801
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot_date(self, x, y, fmt, tz, xdate, ydate, **kwargs)
#    1741             self.yaxis_date(tz)
#    1742
# -> 1743         ret = self.plot(x, y, fmt, **kwargs)
#    1744
#    1745         self.autoscale_view()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
# -> 1668             self.add_line(line)
#    1669         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1670         return lines
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1898             line.set_clip_path(self.patch)
#    1899
# -> 1900         self._update_line_limits(line)
#    1901         if not line.get_label():
#    1902             line.set_label('_line%d' % len(self.lines))
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1920         Figures out the data limit of the given line, updating self.dataLim.
#    1921         """
# -> 1922         path = line.get_path()
#    1923         if path.vertices.size == 0:
#    1924             return
#
# ~\Anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# ~\Anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     672             x = self._x
#     673         if always or self._invalidy:
# --> 674             yconv = self.convert_yunits(self._yorig)
#     675             y = _to_unmasked_float_array(yconv).ravel()
#     676         else:
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in convert_yunits(self, y)
#     190         if ax is None or ax.yaxis is None:
#     191             return y
# --> 192         return ax.yaxis.convert_units(y)
#     193
#     194     @property
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1552         except Exception as e:
#    1553             raise munits.ConversionError('Failed to convert value(s) to axis '
# -> 1554                                          f'units: {x!r}') from e
#    1555         return ret
#    1556
#
# ConversionError: Failed to convert value(s) to axis units: array([<matplotlib.dates.DateFormatter object at 0x00000240DDB55EB8>],
#       dtype=object)
# Error in callback <function flush_figures at 0x00000240CA25BD90> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <C:\Users\JC\Anaconda3\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2643             renderer.stop_rasterizing()
#    2644
# -> 2645         mimage._draw_list_compositing_images(renderer, self, artists)
#    2646
#    2647         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1202         renderer.open_group(__name__)
#    1203
# -> 1204         ticks_to_draw = self._update_ticks()
#    1205         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1206                                                                 renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1079         """
#    1080         major_locs = self.get_majorticklocs()
# -> 1081         major_labels = self.major.formatter.format_ticks(major_locs)
#    1082         major_ticks = self.get_major_ticks(len(major_locs))
#    1083         self.major.formatter.set_locs(major_locs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     257         """Return the tick labels for all the ticks at once."""
#     258         self.set_locs(values)
# --> 259         return [self(value, i) for i, value in enumerate(values)]
#     260
#     261     def format_data(self, value):
#
# ~\Anaconda3\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     257         """Return the tick labels for all the ticks at once."""
#     258         self.set_locs(values)
# --> 259         return [self(value, i) for i, value in enumerate(values)]
#     260
#     261     def format_data(self, value):
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in __call__(self, x, pos)
#     152             return ""
#     153         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 154                      for k, v in self._units.items()}
#     155         return r_mapping.get(int(np.round(x)), '')
#     156
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in <dictcomp>(.0)
#     152             return ""
#     153         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 154                      for k, v in self._units.items()}
#     155         return r_mapping.get(int(np.round(x)), '')
#     156
#
# KeyboardInterrupt:

# %%
#sns.baplot(x='Occur_Date' y=)

#Date = crime_df['Occur_Date']
#Date2 = drime_df["Possible_Date"]

#plt.plot_date(Date, Date2, linestyle='solid')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occur_Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-d676b19072a3> in <module>
# ----> 1 Date = crime_df['Occur_Date']
#       2 Date2 = drime_df["Possible_Date"]
#       3
#       4 plt.plot_date(Date, Date2, linestyle='solid')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occur_Date'

# %%
#plt.plot_date(Date, Date2, linestyle='solid')

#plt.gcf().autofmt_xdate()

#date_format = mpl_dates.DateFormatter('%b, %d, %Y')

#plt.gca().xaxis.set_major_formatter(date_format)

#plt.title('Crime By Date')
#plt.xlabel('Date')
#plt.ylabel('Number Of Crimes')

# %%
#plt.plot_dates(dates, y, linestyle='solid')

#plt.gcf().autofmt_xdate()
